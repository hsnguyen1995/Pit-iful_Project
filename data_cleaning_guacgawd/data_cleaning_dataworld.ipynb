# %%
# Import dependencies
import pandas as pd

# Read and load csv
avocado_path = "../Data/avocado.csv"
avo_csv = pd.read_csv(avocado_path, parse_dates=['Date'], dayfirst=True)

avo_csv.head(50)
# Out:
#          Date  AveragePrice  Total Volume  Small Hass  Large Hass  XL Hass  \
# 0  2015-12-27          1.33      64236.62     1036.74    54454.85    48.16
# 1  2015-12-20          1.35      54876.98      674.28    44638.81    58.33
# 2  2015-12-13          0.93     118220.22      794.70   109149.67   130.50
# 3  2015-12-06          1.08      78992.15     1132.00    71976.41    72.58
# 4  2015-11-29          1.28      51039.60      941.48    43838.39    75.78
# 5  2015-11-22          1.26      55979.78     1184.27    48067.99    43.61
# 6  2015-11-15          0.99      83453.76     1368.92    73672.72    93.26
# 7  2015-11-08          0.98     109428.33      703.75   101815.36    80.00
# 8  2015-11-01          1.02      99811.42     1022.15    87315.57    85.34
# 9  2015-10-25          1.07      74338.76      842.40    64757.44   113.00
# 10 2015-10-18          1.12      84843.44      924.86    75595.85   117.07
# ...

# %%
# check data types
avo_csv.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# Small Hass             float64
# Large Hass             float64
# XL Hass                float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# Type                    object
# Year                     int64
# Region                  object
# dtype: object

# %%
# Check for NaNs
avo_csv.count()
# Out:
# Date            18249
# AveragePrice    18249
# Total Volume    18249
# Small Hass      18249
# Large Hass      18249
# XL Hass         18249
# Total Bags      18249
# Small Bags      18249
# Large Bags      18249
# XLarge Bags     18249
# Type            18249
# Year            18249
# Region          18249
# dtype: int64

# %%
#This code was used before finding out about the pasre_date parameter

# Extract days and months from date column
# dayList = []
# monthList = []
# dayExtract = avo_csv["Date"].str.split("/").str[0]
# monthExtract = avo_csv["Date"].str.split("/").str[1]

# Remove leading 0's in month values because of inconsistent month format
# for i in monthExtract:
#     while i[0] == "0":
#         i = i[1:]
#     monthList.append(i)

# %%
# Load months column into existing DF
# avo_csv["Month"] = monthList

# avo_csv

# %%
# Convert Year column to string and concatenate with Month column to get Month/Year column
# avo_csv["Year"] = avo_csv["Year"].astype(str)
# avo_csv["Month/Year"] = avo_csv["Month"] + "/" + avo_csv["Year"]

# avo_csv.columns

# %%
# Rearrange columns, drop unnecessary columns
avo_df = avo_csv[['Date', 'AveragePrice', 'Total Volume', 'Small Hass', 'Large Hass', 'XL Hass', 'Type', 'Region']]
avo_df
# Out:
#             Date  AveragePrice  Total Volume  Small Hass  Large Hass  XL Hass  \
# 0     2015-12-27          1.33      64236.62     1036.74    54454.85    48.16
# 1     2015-12-20          1.35      54876.98      674.28    44638.81    58.33
# 2     2015-12-13          0.93     118220.22      794.70   109149.67   130.50
# 3     2015-12-06          1.08      78992.15     1132.00    71976.41    72.58
# 4     2015-11-29          1.28      51039.60      941.48    43838.39    75.78
# ...          ...           ...           ...         ...         ...      ...
# 18244 2018-02-04          1.63      17074.83     2046.96     1529.20     0.00
# 18245 2018-01-28          1.71      13888.04     1191.70     3431.50     0.00
# 18246 2018-01-21          1.87      13766.76     1191.92     2452.79   727.94
# 18247 2018-01-14          1.93      16205.22     1527.63     2981.04   727.01
# 18248 2018-01-07          1.62      17489.58     2894.77     2356.13   224.53
#
# ...

# %%
avo_df = avo_df.rename(columns = {
    'Month/Year':'MonthYear', 
    'Total Volume':'TotalVolume',
    'Small Hass':'SmallHass',
    'Large Hass':'LargeHass',
    'XL Hass':'XLHass'
})

# %%
avo_df.head()
# Out:
#         Date  AveragePrice  TotalVolume  SmallHass  LargeHass  XLHass  \
# 0 2015-12-27          1.33     64236.62    1036.74   54454.85   48.16
# 1 2015-12-20          1.35     54876.98     674.28   44638.81   58.33
# 2 2015-12-13          0.93    118220.22     794.70  109149.67  130.50
# 3 2015-12-06          1.08     78992.15    1132.00   71976.41   72.58
# 4 2015-11-29          1.28     51039.60     941.48   43838.39   75.78
#
#            Type  Region
# 0  conventional  Albany
# 1  conventional  Albany
# 2  conventional  Albany
# 3  conventional  Albany
# 4  conventional  Albany

# %%
avo_df.Region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
# Export DF as csv
avo_df.to_csv("../Data/avocado_clean.csv", index=False, header=True)
