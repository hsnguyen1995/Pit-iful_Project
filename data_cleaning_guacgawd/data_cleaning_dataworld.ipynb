# %%
# Import dependencies
import pandas as pd

# Read and load csv
avocado_path = "../Data/avocado.csv"
avo_csv = pd.read_csv(avocado_path)

avo_csv
# Out:
#              Date  AveragePrice  Total Volume  Small Hass  ...  XLarge Bags          Type  Year            Region
# 0      27/12/2015          1.33      64236.62     1036.74  ...          0.0  conventional  2015            Albany
# 1      20/12/2015          1.35      54876.98      674.28  ...          0.0  conventional  2015            Albany
# 2      13/12/2015          0.93     118220.22      794.70  ...          0.0  conventional  2015            Albany
# 3       6/12/2015          1.08      78992.15     1132.00  ...          0.0  conventional  2015            Albany
# 4      29/11/2015          1.28      51039.60      941.48  ...          0.0  conventional  2015            Albany
# ...           ...           ...           ...         ...  ...          ...           ...   ...               ...
# 18244    4/2/2018          1.63      17074.83     2046.96  ...          0.0       organic  2018  WestTexNewMexico
# ...

# %%
# check data types
avo_csv.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# Small Hass      float64
# Large Hass      float64
# XL Hass         float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# Type             object
# Year              int64
# Region           object
# dtype: object

# %%
# Check for NaNs
avo_csv.count()
# Out:
# Date            18249
# AveragePrice    18249
# Total Volume    18249
# Small Hass      18249
# Large Hass      18249
# XL Hass         18249
# Total Bags      18249
# Small Bags      18249
# Large Bags      18249
# XLarge Bags     18249
# Type            18249
# Year            18249
# Region          18249
# Month           18249
# Month/Year      18249
# dtype: int64

# %%
# Extract month from date column
monthList = []
monthExtract = avo_csv["Date"].str.split("/").str[1]

# Remove leading 0's in month values because of inconsistent month format
for i in monthExtract:
    while i[0] == "0":
        i = i[1:]
    monthList.append(i)

# %%
# Load months column into existing DF
avo_csv["Month"] = monthList

avo_csv
# Out:
#              Date  AveragePrice  Total Volume  Small Hass  ...          Type  Year            Region  Month
# 0      27/12/2015          1.33      64236.62     1036.74  ...  conventional  2015            Albany     12
# 1      20/12/2015          1.35      54876.98      674.28  ...  conventional  2015            Albany     12
# 2      13/12/2015          0.93     118220.22      794.70  ...  conventional  2015            Albany     12
# 3       6/12/2015          1.08      78992.15     1132.00  ...  conventional  2015            Albany     12
# 4      29/11/2015          1.28      51039.60      941.48  ...  conventional  2015            Albany     11
# ...           ...           ...           ...         ...  ...           ...   ...               ...    ...
# 18244    4/2/2018          1.63      17074.83     2046.96  ...       organic  2018  WestTexNewMexico      2
# 18245  28/01/2018          1.71      13888.04     1191.70  ...       organic  2018  WestTexNewMexico      1
# ...

# %%
# Convert Year column to string and concatenate with Month column to get Month/Year column
avo_csv["Year"] = avo_csv["Year"].astype(str)
avo_csv["Month/Year"] = avo_csv["Month"] + "/" + avo_csv["Year"]

avo_csv.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', 'Small Hass', 'Large Hass',
#        'XL Hass', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',
#        'Type', 'Year', 'Region', 'Month', 'Month/Year'],
#       dtype='object')

# %%
# Rearrange columns, drop unnecessary columns
final_avo_df = avo_csv[['Month/Year', 'AveragePrice', 'Total Volume', 'Small Hass', 'Large Hass', 'XL Hass', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'Type', 'Region']]
final_avo_df
# Out:
#       Month/Year  AveragePrice  Total Volume  Small Hass  ...  Large Bags  XLarge Bags          Type            Region
# 0        12/2015          1.33      64236.62     1036.74  ...       93.25          0.0  conventional            Albany
# 1        12/2015          1.35      54876.98      674.28  ...       97.49          0.0  conventional            Albany
# 2        12/2015          0.93     118220.22      794.70  ...      103.14          0.0  conventional            Albany
# 3        12/2015          1.08      78992.15     1132.00  ...      133.76          0.0  conventional            Albany
# 4        11/2015          1.28      51039.60      941.48  ...      197.69          0.0  conventional            Albany
# ...          ...           ...           ...         ...  ...         ...          ...           ...               ...
# 18244     2/2018          1.63      17074.83     2046.96  ...      431.85          0.0       organic  WestTexNewMexico
# ...

# %%
# Export DF as csv
final_avo_df.to_csv("../Data/avocado_clean.csv", index=False, header=True)
