# %%
import pandas as pd

# %%
weeklyavodf=pd.read_csv('WeeklyAvoReport - Table 1.csv', header=[0,3])
weeklyavodf.iloc[22, 0]='Jun 9-(32)'
actualweeklyavodf=weeklyavodf.iloc[:52, :]
actualweeklyavodf
# Out:
#    2019 California Crop Weekly Harvest Projection\nWeekly Crop Movement vs. Distribution Projections All Varieties  \
#                                                                                                      (CAC W ee k)
# 0                                        Jan 6 - (10)
# 1                                       Jan 13 - (11)
# 2                                       Jan 20 - (12)
# 3                                        Jan 27- (13)
# 4                                        Feb 3 - (14)
# 5                                       Feb 10 - (15)
# 6                                      Feb 17 - (16 )
# 7                                       Feb 24 - (17)
# 8                                       Mar 3  - (18)
# 9                                       Mar 10 - (19)
# 10                                      Mar 17 - (20)
# 11                                      Mar 24 - (21)
# 12                                     Mar 31 - (22 )
# ...

# %%
actualweeklyavodf.to_csv('trueweeklyavoreportca.csv')

# %%
totalinfosummary=weeklyavodf.iloc[54:57, :5]
totalinfosummary
# Out:
#    2019 California Crop Weekly Harvest Projection\nWeekly Crop Movement vs. Distribution Projections All Varieties  \
#                                                                                                      (CAC W ee k)
# 54                                           %of Crop
# 55                                          Crop Size
# 56                                      Crop Variance
#
#    Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0 Unnamed: 4_level_0
#          CropEstimate             Update            Harvest          Shipments
# 54               100%               100%               125%               123%
# 55        175,000,000        170,000,000      LefttoHarvest       Left to Ship
# 56         37,426,993         42,249,501       (42,150,401)       (38,594,522)

# %%
totalinfosummary.to_csv('totalweeklyinfosummaryca.csv')
